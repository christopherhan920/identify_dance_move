# %% [markdown]
# # Identify Dance Move: Transfer Learning
#
# ## Part 1: Load Videos, Preprocess, and Extract Features

# %%
from tensorflow import keras
import tensorflow as tf
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

import cv2
import os

# %% [markdown]
# Following the tutorial from here: https://keras.io/examples/vision/video_classification/

# %%
IMG_SIZE = 224
BATCH_SIZE = 64
EPOCHS = 10

MAX_SEQ_LENGTH = 20
NUM_FEATURES = 2048

# %%
def crop_center_square(frame):
    y, x = frame.shape[0:2]
    min_dim = min(y, x)
    start_x = (x // 2) - (min_dim // 2)
    start_y = (y // 2) - (min_dim // 2)
    return frame[start_y : start_y + min_dim, start_x : start_x + min_dim]


def load_video(path, max_frames=0, resize=(IMG_SIZE, IMG_SIZE)):
    cap = cv2.VideoCapture(path)
    frames = []
    try:
        while True:
            ret, frame = cap.read()
            if not ret:
                break
            frame = crop_center_square(frame)
            frame = cv2.resize(frame, resize)
            frame = frame[:, :, [2, 1, 0]]
            frames.append(frame)

            if len(frames) == max_frames:
                break
    finally:
        cap.release()
    return np.array(frames)

# %%
def build_feature_extractor():
    feature_extractor = keras.applications.InceptionV3(
        weights="imagenet",
        include_top=False,
        pooling="avg",
        input_shape=(IMG_SIZE, IMG_SIZE, 3),
    )
    preprocess_input = keras.applications.inception_v3.preprocess_input

    inputs = keras.Input((IMG_SIZE, IMG_SIZE, 3))
    preprocessed = preprocess_input(inputs)

    outputs = feature_extractor(preprocessed)
    return keras.Model(inputs, outputs, name="feature_extractor")

feature_extractor = build_feature_extractor()

# %%
moves = os.listdir('data')
print(moves)
# Out:
# ['Stick and Roll', 'Brooklyn', 'Charleston', 'Monastery']

# %%
label_processor = keras.layers.StringLookup(
    num_oov_indices=0, vocabulary=moves
)
print(label_processor.get_vocabulary())
# Out:
# ['Stick and Roll', 'Brooklyn', 'Charleston', 'Monastery']

# %%
# iterate through each folder and file and add the file name and label to a table

filenames = []
labels = []

for move in moves:
    filenames = filenames + os.listdir('data/{}'.format(move))
    labels = labels + [move] * len(os.listdir('data/{}'.format(move)))

df = pd.DataFrame({'video_name': filenames, 'tag': labels})
print(df)
# Out:
#                                   video_name             tag
# 0                               IMG_4742.MOV  Stick and Roll
# 1   2B780CEE-3D09-4820-BEFD-CFDFF074F444.mov  Stick and Roll
# 2                               IMG_4753.MOV  Stick and Roll
# 3   2B93BBED-F225-4523-9DC6-31ABB7347F2F.mov  Stick and Roll
# 4   24FD3C61-03D2-4BAA-9F27-BE0A1743C71A.mov  Stick and Roll
# 5                               IMG_4686.MOV  Stick and Roll
# 6   2116E609-5176-49C8-9F92-0B97EF341606.mov  Stick and Roll
# 7                               IMG_4690.MOV  Stick and Roll
# 8                               IMG_4688.MOV  Stick and Roll
# 9                               IMG_4703.MOV  Stick and Roll
# 10  8EFD7A3A-DF83-4146-99C8-2233A1B50554.mov  Stick and Roll
# 11                              IMG_4738.MOV  Stick and Roll
# 12                              IMG_9223.mov  Stick and Roll
# 13                              IMG_4699.MOV  Stick and Roll
# 14              RPReplay_Final1658454103.mp4  Stick and Roll
# 15                              IMG_4749.MOV  Stick and Roll
# 16                              IMG_4759.MOV  Stick and Roll
# 17  2C30C94B-63BA-47A1-88C5-D2228609EA98.mov        Brooklyn
# 18              RPReplay_Final1658454035.mp4        Brooklyn
# 19  0DBBC49D-DD09-4D93-8B2E-5A8E2D9C87AD.mov        Brooklyn
# 20                              IMG_9221.mov        Brooklyn
# 21  1D94BB45-0578-489C-A52F-418B6F1279F7.mov        Brooklyn
# 22  AF8F2845-671A-40EE-A516-7F67A0AD385E.mov        Brooklyn
# 23                              IMG_4740.MOV      Charleston
# 24                              IMG_4755.MOV      Charleston
# 25                              IMG_4747.MOV      Charleston
# 26              RPReplay_Final1658454131.mp4      Charleston
# 27                              IMG_4744.MOV      Charleston
# 28                              IMG_4694.MOV      Charleston
# 29                              IMG_4695.MOV      Charleston
# 30  92361FAE-A84E-4B4B-85B6-DE199E76893A.mov      Charleston
# 31                              IMG_4702.MOV      Charleston
# 32  698334CC-5E67-4CE3-8C7F-A1390D0488B9.mov      Charleston
# 33                              IMG_4698.MOV      Charleston
# 34  1C956901-7273-49CA-B48D-82EEF87CDB45.mov      Charleston
# 35                              IMG_9222.mov      Charleston
# 36                              IMG_4761.MOV      Charleston
# 37  AAE51822-E3FE-43D0-ABC1-7EB39DFA042B.mov      Charleston
# 38  C875154C-4887-4A91-812B-3E314A7E080E.mov      Charleston
# 39                              IMG_4754.MOV       Monastery
# 40                              IMG_4743.MOV       Monastery
# 41  F795CDC5-9FD9-47BA-BA5C-560641AB9E6C.mov       Monastery
# 42  4C08206C-C5B8-454C-AAF3-3CD0A06FEA45.mov       Monastery
# 43                              IMG_4687.MOV       Monastery
# 44                              IMG_4691.MOV       Monastery
# 45                              IMG_4689.MOV       Monastery
# 46                              IMG_4700.MOV       Monastery
# 47                              IMG_9224.mov       Monastery
# 48                              IMG_4704.MOV       Monastery
# 49                              IMG_4739.MOV       Monastery
# 50  BDC1709F-3A46-423A-B642-3628BCC603EA.mov       Monastery
# 51  5D8BB37D-643F-4976-9104-BBDD2E7B1CAC.mov       Monastery
# 52                              IMG_4760.MOV       Monastery
# 53                              IMG_4748.MOV       Monastery
# 54  78E05121-9DDF-4AC2-82D8-D08DA1257D3C.mov       Monastery
# 55              RPReplay_Final1658454066.mp4       Monastery

# %%
train_df, test_df = train_test_split(df, test_size = 0.2, random_state = 150)

# %%
train_df
# Out:
#                                   video_name             tag
# 20                              IMG_9221.mov        Brooklyn
# 39                              IMG_4754.MOV       Monastery
# 51  5D8BB37D-643F-4976-9104-BBDD2E7B1CAC.mov       Monastery
# 21  1D94BB45-0578-489C-A52F-418B6F1279F7.mov        Brooklyn
# 31                              IMG_4702.MOV      Charleston
# 15                              IMG_4749.MOV  Stick and Roll
# 4   24FD3C61-03D2-4BAA-9F27-BE0A1743C71A.mov  Stick and Roll
# 43                              IMG_4687.MOV       Monastery
# 32  698334CC-5E67-4CE3-8C7F-A1390D0488B9.mov      Charleston
# 3   2B93BBED-F225-4523-9DC6-31ABB7347F2F.mov  Stick and Roll
# 33                              IMG_4698.MOV      Charleston
# 0                               IMG_4742.MOV  Stick and Roll
# 10  8EFD7A3A-DF83-4146-99C8-2233A1B50554.mov  Stick and Roll
# 45                              IMG_4689.MOV       Monastery
# 38  C875154C-4887-4A91-812B-3E314A7E080E.mov      Charleston
# 53                              IMG_4748.MOV       Monastery
# 18              RPReplay_Final1658454035.mp4        Brooklyn
# 12                              IMG_9223.mov  Stick and Roll
# 6   2116E609-5176-49C8-9F92-0B97EF341606.mov  Stick and Roll
# 11                              IMG_4738.MOV  Stick and Roll
# 7                               IMG_4690.MOV  Stick and Roll
# 19  0DBBC49D-DD09-4D93-8B2E-5A8E2D9C87AD.mov        Brooklyn
# 1   2B780CEE-3D09-4820-BEFD-CFDFF074F444.mov  Stick and Roll
# 42  4C08206C-C5B8-454C-AAF3-3CD0A06FEA45.mov       Monastery
# 49                              IMG_4739.MOV       Monastery
# 17  2C30C94B-63BA-47A1-88C5-D2228609EA98.mov        Brooklyn
# 13                              IMG_4699.MOV  Stick and Roll
# 47                              IMG_9224.mov       Monastery
# 52                              IMG_4760.MOV       Monastery
# 44                              IMG_4691.MOV       Monastery
# 29                              IMG_4695.MOV      Charleston
# 35                              IMG_9222.mov      Charleston
# 40                              IMG_4743.MOV       Monastery
# 41  F795CDC5-9FD9-47BA-BA5C-560641AB9E6C.mov       Monastery
# 27                              IMG_4744.MOV      Charleston
# 28                              IMG_4694.MOV      Charleston
# 23                              IMG_4740.MOV      Charleston
# 37  AAE51822-E3FE-43D0-ABC1-7EB39DFA042B.mov      Charleston
# 14              RPReplay_Final1658454103.mp4  Stick and Roll
# 55              RPReplay_Final1658454066.mp4       Monastery
# 50  BDC1709F-3A46-423A-B642-3628BCC603EA.mov       Monastery
# 48                              IMG_4704.MOV       Monastery
# 25                              IMG_4747.MOV      Charleston
# 36                              IMG_4761.MOV      Charleston

# %%
def prepare_all_videos(df, root_dir):
    num_samples = len(df)
    video_paths = df["video_name"].values.tolist()
    labels = df["tag"].values
    labels = label_processor(labels[..., None]).numpy()

    # `frame_masks` and `frame_features` are what we will feed to our sequence model.
    # `frame_masks` will contain a bunch of booleans denoting if a timestep is
    # masked with padding or not.
    frame_masks = np.zeros(shape=(num_samples, MAX_SEQ_LENGTH), dtype="bool")
    frame_features = np.zeros(
        shape=(num_samples, MAX_SEQ_LENGTH, NUM_FEATURES), dtype="float32"
    )

    # For each video.
    for idx, path in enumerate(video_paths):
        print('Working on video {}'.format(idx))
        # Gather all its frames and add a batch dimension.
        frames = load_video(os.path.join(root_dir, path))
        frames = frames[None, ...]

        # Initialize placeholders to store the masks and features of the current video.
        temp_frame_mask = np.zeros(shape=(1, MAX_SEQ_LENGTH,), dtype="bool")
        temp_frame_features = np.zeros(
            shape=(1, MAX_SEQ_LENGTH, NUM_FEATURES), dtype="float32"
        )

        # Extract features from the frames of the current video.
        for i, batch in enumerate(frames):
            video_length = batch.shape[0]
            length = min(MAX_SEQ_LENGTH, video_length)
            for j in range(length):
                temp_frame_features[i, j, :] = feature_extractor.predict(
                    batch[None, j, :]
                )
            temp_frame_mask[i, :length] = 1  # 1 = not masked, 0 = masked

        frame_features[idx,] = temp_frame_features.squeeze()
        frame_masks[idx,] = temp_frame_mask.squeeze()

    return (frame_features, frame_masks), labels


train_data, train_labels = prepare_all_videos(train_df, "data/all_combined")
test_data, test_labels = prepare_all_videos(test_df, "data/all_combined")

print(f"Frame features in train set: {train_data[0].shape}")
print(f"Frame masks in train set: {train_data[1].shape}")
# Out:
# Working on video 0
# Working on video 1
# Working on video 2
# Working on video 3
# Working on video 4
# Working on video 5
# Working on video 6
# Working on video 7
# Working on video 8
# Working on video 9
# Working on video 10
# Working on video 11
# Working on video 12
# Working on video 13
# Working on video 14
# Working on video 15
# Working on video 16
# Working on video 17
# Working on video 18
# Working on video 19
# Working on video 20
# Working on video 21
# Working on video 22
# Working on video 23
# Working on video 24
# Working on video 25
# Working on video 26
# Working on video 27
# Working on video 28
# Working on video 29
# Working on video 30
# Working on video 31
# Working on video 32
# Working on video 33
# Working on video 34
# Working on video 35
# Working on video 36
# Working on video 37
# Working on video 38
# Working on video 39
# Working on video 40
# Working on video 41
# Working on video 42
# Working on video 43
# Working on video 0
# Working on video 1
# Working on video 2
# Working on video 3
# Working on video 4
# Working on video 5
# Working on video 6
# Working on video 7
# Working on video 8
# Working on video 9
# Working on video 10
# Working on video 11
# Frame features in train set: (44, 20, 2048)
# Frame masks in train set: (44, 20)

# %%
print(train_data)
# Out:
# (array([[[0.00000000e+00, 5.22811860e-02, 1.47548243e-01, ...,
#          2.74500363e-02, 1.09732188e-01, 3.82891387e-01],
#         [2.09405139e-01, 9.99020506e-03, 3.90151590e-01, ...,
#          4.21903649e-04, 7.39076734e-02, 5.30389488e-01],
#         [2.19072402e-01, 2.83084740e-03, 3.36810708e-01, ...,
#          0.00000000e+00, 6.72419816e-02, 9.39447761e-01],
#         ...,
#         [2.17002407e-01, 1.50484383e-01, 4.12761539e-01, ...,
#          1.38557166e-01, 8.90455619e-02, 1.12989771e+00],
#         [3.31145018e-01, 7.40275607e-02, 4.81291592e-01, ...,
#          1.10463314e-01, 5.28983623e-02, 9.85677779e-01],
#         [1.19318552e-01, 1.15119860e-01, 5.43458700e-01, ...,
#          1.42023310e-01, 1.12287290e-01, 1.08493936e+00]],
#
#        [[3.56361777e-01, 5.56771457e-01, 8.96400690e-01, ...,
#          1.81419230e+00, 2.15969586e+00, 6.47249222e-01],
#         [4.58724469e-01, 4.61036682e-01, 6.91684365e-01, ...,
#          1.90414500e+00, 2.03265429e+00, 4.22077209e-01],
#         [3.56523395e-01, 2.84213752e-01, 6.58372581e-01, ...,
#          1.94305360e+00, 1.55232930e+00, 3.67731936e-02],
#         ...,
#         [4.97717589e-01, 6.39216244e-01, 6.38745546e-01, ...,
#          4.84663695e-01, 1.71103704e+00, 6.80934042e-02],
#         [5.78752518e-01, 6.41102016e-01, 5.12090921e-01, ...,
#          6.08607650e-01, 1.50249577e+00, 1.97199062e-01],
#         [4.92678493e-01, 7.25549996e-01, 3.84018719e-01, ...,
#          5.92980206e-01, 1.47253466e+00, 1.88943520e-02]],
#
#        [[6.09697290e-02, 1.92970023e-01, 6.38861120e-01, ...,
#          4.24213009e-03, 9.13200736e-01, 7.67553806e-01],
#         [5.84765822e-02, 2.12148458e-01, 5.53554296e-01, ...,
#          0.00000000e+00, 1.01001203e+00, 8.80185604e-01],
#         [1.34807289e-01, 2.55754977e-01, 6.17452443e-01, ...,
#          0.00000000e+00, 1.05304372e+00, 3.19253236e-01],
#         ...,
#         [1.10295355e-01, 2.26757541e-01, 3.26666534e-01, ...,
#          0.00000000e+00, 4.02211219e-01, 1.02972257e+00],
#         [8.90088081e-02, 2.49204710e-01, 1.45051837e-01, ...,
#          3.51741188e-03, 8.58691275e-01, 1.18678331e+00],
#         [2.16572620e-02, 1.89690396e-01, 1.59186408e-01, ...,
#          1.68986071e-03, 8.92019510e-01, 7.52742767e-01]],
#
#        ...,
#
#        [[1.37207353e+00, 2.22496331e-01, 1.06769013e+00, ...,
#          2.53727764e-01, 1.12801862e+00, 2.37937316e-01],
#         [1.76725721e+00, 1.27768204e-01, 7.32197165e-01, ...,
#          4.07235801e-01, 1.11971080e+00, 9.35153589e-02],
#         [1.52046037e+00, 2.25844502e-01, 7.94903994e-01, ...,
#          5.39184213e-01, 1.31703889e+00, 1.79327667e-01],
#         ...,
#         [6.49768531e-01, 2.58622449e-02, 3.65537226e-01, ...,
#          8.15145135e-01, 1.73647419e-01, 3.64049911e-01],
#         [8.96734178e-01, 1.60492346e-01, 2.97522008e-01, ...,
#          1.15094066e+00, 2.88524896e-01, 3.27151716e-01],
#         [1.40751314e+00, 6.51860297e-01, 8.19886446e-01, ...,
#          5.58109522e-01, 3.51626039e-01, 2.64061447e-02]],
#
#        [[1.96118605e+00, 2.93137670e-01, 1.76252031e+00, ...,
#          3.17348510e-01, 1.86582339e+00, 7.67224491e-01],
#         [1.93317187e+00, 3.35844964e-01, 1.79522645e+00, ...,
#          5.44865668e-01, 1.83372116e+00, 8.08964610e-01],
#         [2.04028440e+00, 4.09004778e-01, 1.86240435e+00, ...,
#          4.44724530e-01, 1.92948711e+00, 9.92451012e-01],
#         ...,
#         [1.38428295e+00, 3.53585005e-01, 1.05800581e+00, ...,
#          1.83193251e-01, 1.36738765e+00, 1.17857647e+00],
#         [1.02213359e+00, 2.54540682e-01, 1.09020281e+00, ...,
#          3.55214536e-01, 1.24041271e+00, 1.43236661e+00],
#         [9.42845941e-01, 1.31867528e-01, 1.42647398e+00, ...,
#          1.97751541e-02, 1.52904403e+00, 1.17839277e+00]],
#
#        [[5.92489362e-01, 5.48158765e-01, 1.65111542e+00, ...,
#          1.13049157e-01, 9.95197892e-01, 3.21023822e-01],
#         [7.74870992e-01, 7.71148741e-01, 1.30789769e+00, ...,
#          1.82918623e-01, 7.77350783e-01, 4.42237675e-01],
#         [4.05113131e-01, 6.90477848e-01, 1.34567702e+00, ...,
#          1.34769842e-01, 1.14857173e+00, 5.13925791e-01],
#         ...,
#         [1.14843512e+00, 2.87895530e-01, 1.26823926e+00, ...,
#          3.34163278e-01, 1.01127005e+00, 2.29556605e-01],
#         [1.36620557e+00, 3.94070923e-01, 1.25908077e+00, ...,
#          2.33481824e-01, 1.21001637e+00, 3.74854773e-01],
#         [1.48078978e+00, 3.03895473e-01, 1.35173798e+00, ...,
#          3.86491805e-01, 1.30858243e+00, 4.35628533e-01]]], dtype=float32), array([[ True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True],
#        [ True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True],
#        [ True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True],
#        [ True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True],
#        [ True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True],
#        [ True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True],
#        [ True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True],
#        [ True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True],
#        [ True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True],
#        [ True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True],
#        [ True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True],
#        [ True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True],
#        [ True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True],
#        [ True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True],
#        [ True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True],
#        [ True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True],
#        [ True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True],
#        [ True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True],
#        [ True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True],
#        [ True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True],
#        [ True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True],
#        [ True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True],
#        [ True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True],
#        [ True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True],
#        [ True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True],
#        [ True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True],
#        [ True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True],
#        [ True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True],
#        [ True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True],
#        [ True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True],
#        [ True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True],
#        [ True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True],
#        [ True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True],
#        [ True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True],
#        [ True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True],
#        [ True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True],
#        [ True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True],
#        [ True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True],
#        [ True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True],
#        [ True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True],
#        [ True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True],
#        [ True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True],
#        [ True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True],
#        [ True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True]]))

# %%
print(train_labels)
# Out:
# [[1]
#  [3]
#  [3]
#  [1]
#  [2]
#  [0]
#  [0]
#  [3]
#  [2]
#  [0]
#  [2]
#  [0]
#  [0]
#  [3]
#  [2]
#  [3]
#  [1]
#  [0]
#  [0]
#  [0]
#  [0]
#  [1]
#  [0]
#  [3]
#  [3]
#  [1]
#  [0]
#  [3]
#  [3]
#  [3]
#  [2]
#  [2]
#  [3]
#  [3]
#  [2]
#  [2]
#  [2]
#  [2]
#  [0]
#  [3]
#  [3]
#  [3]
#  [2]
#  [2]]

# %% [markdown]
# ## Part 2: Fit Models

# %% [markdown]
# ## Part 3: Register the model
# Plan is to set up MLFlow model registry.
#
# After we register the model, it's ready to be consumed by an application, in our case the web UI.

# %% [markdown]
# ## Part 4: Consume the model
#
# This phase will happen outside of this notebook, where the UI will pull our trained model, process users' video uploads, feeds it through our model, and displays the results.
